# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

sns.set()

# %%
cov_data = pd.read_csv('data/3-5-1-cov.csv')
cov_data.head()
# Out:
#       x   y
# 0  18.5  34
# 1  18.7  39
# 2  19.1  41
# 3  19.7  38
# 4  21.5  45

# %%
lineplot_df = pd.read_csv('data/3-7-1-lineplot-data.csv')
lineplot_df.head()
# Out:
#    x  y
# 0  0  2
# 1  1  3
# 2  2  4
# 3  3  3
# 4  4  5

# %%
fish_multi = pd.read_csv('data/3-6-1-fish_multi.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
sns.scatterplot(x='x', y='y', data=cov_data, color='black')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.lineplot(x='x', y='y', data=lineplot_df, color='black')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.relplot(x='x', y='y', data=cov_data, color='black')

# %%
penguins = sns.load_dataset('penguins')
sns.pairplot(hue='species', data=penguins, palette='gray')
